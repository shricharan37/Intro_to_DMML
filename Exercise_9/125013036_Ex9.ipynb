# %%
#Name:Shricharan
#Register Number - 125013036
#Date-26/03/2024
#BIN2023R01 - INTRODUCTION TO DATAMINING & MACHINE LEARNING FOR BIOINFORMATICS
#Exercise9
#Version - 1.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
data=pd.read_csv("Cervical cancer.csv")
data
# Out:
#     behavior_sexualRisk  behavior_eating  behavior_personalHygine  \
# 0                    10               13                       12
# 1                    10               11                       11
# 2                    10               15                        3
# 3                    10               11                       10
# 4                     8               11                        7
# ..                  ...              ...                      ...
# 64                   10               15                        8
# 65                   10               13                       11
# 66                   10               12                       13
# 67                   10               14                       14
# 68                   10               12                       15
#
#     intention_aggregation  intention_commitment  attitude_consistency  \
# 0                       4                     7                     9
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Cervical cancer.csv')

columns_to_plot = ['behavior_sexualRisk', 'behavior_eating', 'behavior_personalHygine',
                   'intention_aggregation', 'intention_commitment', 'attitude_consistency',
                   'attitude_spontaneity', 'norm_significantPerson', 'norm_fulfillment',
                   'perception_vulnerability', 'perception_severity', 'motivation_strength',
                   'motivation_willingness', 'socialSupport_emotionality', 'socialSupport_appreciation',
                   'socialSupport_instrumental', 'empowerment_knowledge', 'empowerment_abilities',
                   'empowerment_desires', 'ca_cervix']

num_plots = len(columns_to_plot)
num_cols = 3
num_rows = -(-num_plots // num_cols)
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 5*num_rows))

for ax, col in zip(axes.flatten(), columns_to_plot):
    ax.scatter(df.index, df[col], color='blue', alpha=0.6)
    ax.set_title(col)
    ax.set_xlabel('Index')
    ax.set_ylabel(col)

plt.tight_layout()
plt.show()

# %%
df.isnull().values.any()
# Out:
# False

# %%
data=data.select_dtypes(include='number')
from scipy import stats
z_scores_combined = np.abs(stats.zscore(data))

threshold = 3
df = data[(z_scores_combined < threshold).all(axis=1)]
df
# Out:
#     behavior_sexualRisk  behavior_eating  behavior_personalHygine  \
# 0                    10               13                       12
# 1                    10               11                       11
# 2                    10               15                        3
# 3                    10               11                       10
# 4                     8               11                        7
# ..                  ...              ...                      ...
# 64                   10               15                        8
# 65                   10               13                       11
# 66                   10               12                       13
# 67                   10               14                       14
# 68                   10               12                       15
#
#     intention_aggregation  intention_commitment  attitude_consistency  \
# 0                       4                     7                     9
# ...

# %%
features = df.iloc[:, :-1]
target = df.iloc[:, -1]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
print(scaled_features)
# Out:
# [[ 0.2744004   0.06262243  0.31637659 ...  0.32571084  0.43299327
#   -0.55582992]
#  [ 0.2744004  -0.93933644 -0.0155595  ... -1.24330483 -1.21091337
#   -1.47980694]
#  [ 0.2744004   1.06458129 -2.67104829 ... -1.69159503 -1.44575718
#    1.06112985]
#  ...
#  [ 0.2744004  -0.438357    0.64831269 ... -0.34672445 -0.50638196
#    0.13715284]
#  [ 0.2744004   0.56360186  0.98024879 ...  0.32571084  0.43299327
#   -0.32483567]
#  [ 0.2744004  -0.438357    1.31218489 ...  0.99814613  0.43299327
#    0.8301356 ]]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.2, random_state=42)
print("x train shape:", x_train.shape)
print("x test shape:", x_test.shape)
print("y train shape:", y_train.shape)
print("y test shape:", y_test.shape)
# Out:
# x train shape: (51, 19)
# x test shape: (13, 19)
# y train shape: (51,)
# y test shape: (13,)

# %%
clf = GaussianNB()

# %%
clf.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

precision = precision_score(y_test, y_pred)

print("Precision:", precision)
# Out:
# Accuracy: 0.7692307692307693
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84         8
#            1       1.00      0.40      0.57         5
#
#     accuracy                           0.77        13
#    macro avg       0.86      0.70      0.71        13
# weighted avg       0.83      0.77      0.74        13
#
#
# Confusion Matrix:
# [[8 0]
#  [3 2]]
# Precision: 1.0

# %%
custom_data = {
    'behavior_sexualRisk': 0.6,
    'behavior_eating': 0.7,
    'behavior_personalHygine': 0.6,
    'intention_aggregation': 0.5,
    'intention_commitment': 0.4,
    'attitude_consistency': 0.4,
    'attitude_spontaneity': 0.3,
    'norm_significantPerson': 0.4,
    'norm_fulfillment': 0.7,
    'perception_vulnerability': 0.3,
    'perception_severity': 0.3,
    'motivation_strength': 0.2,
    'motivation_willingness': 0.6,
    'socialSupport_emotionality': 0.1,
    'socialSupport_appreciation': 0.1,
    'socialSupport_instrumental': 0.1,
    'empowerment_knowledge': 0.2,
    'empowerment_abilities': 0.3,
    'empowerment_desires': 0.2
}

custom_data_df = pd.DataFrame([custom_data])

custom_predictions = clf.predict(custom_data_df)

prediction_label = "Presence" if custom_predictions[0] == 1 else "Absence"

print("Predicted class for custom data:", prediction_label)
# Out:
# Predicted class for custom data: Presence
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but GaussianNB was fitted without feature names
#   warnings.warn(

# %%
#SVM
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

classifier = SVC(kernel='rbf', random_state=0)
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
accuracy1 = accuracy_score(y_test, y_pred)
precision1 = precision_score(y_test, y_pred, average='binary')
recall1 = recall_score(y_test, y_pred, average='binary')
f11 = f1_score(y_test, y_pred, average='binary')

print("Accuracy:", accuracy1)
print("Precision:", precision1)
print("Recall:", recall1)
print("F1-score:", f11)
# Out:
# Accuracy: 0.9230769230769231
# Precision: 1.0
# Recall: 0.8
# F1-score: 0.888888888888889

# %%
#decision_tree
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix
import joblib

c= DecisionTreeClassifier()
c.fit(x_train, y_train)
plot_tree(c)
# Out:
# [Text(0.36363636363636365, 0.9166666666666666, 'x[17] <= -0.741\ngini = 0.398\nsamples = 51\nvalue = [37, 14]'),
#  Text(0.18181818181818182, 0.75, 'x[15] <= -1.584\ngini = 0.43\nsamples = 16\nvalue = [5, 11]'),
#  Text(0.09090909090909091, 0.5833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2727272727272727, 0.5833333333333334, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.5454545454545454, 0.75, 'x[0] <= -1.322\ngini = 0.157\nsamples = 35\nvalue = [32, 3]'),
#  Text(0.45454545454545453, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6363636363636364, 0.5833333333333334, 'x[11] <= -1.012\ngini = 0.111\nsamples = 34\nvalue = [32, 2]'),
#  Text(0.45454545454545453, 0.4166666666666667, 'x[12] <= 1.035\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.36363636363636365, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5454545454545454, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
# ...

# %%
#decision_tree
y_pred = c.predict(x_test)
cm=confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[8 0]
#  [2 3]]

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      1.00      1.00         5
#
#     accuracy                           1.00        13
#    macro avg       1.00      1.00      1.00        13
# weighted avg       1.00      1.00      1.00        13
#
# Confusion Matrix:
# [[8 0]
#  [0 5]]
